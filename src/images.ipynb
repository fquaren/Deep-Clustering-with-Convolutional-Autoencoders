# %%
from build_and_save_features import load_dataset, read_images
import config as cfg
import os
from skimage import io
import numpy as np
import cv2
from matplotlib import pyplot as plt
from pprint import pprint
import glob
import shutil

# %%
path = "/home/fquaren/unimib/tesi/data/raw/all/"
print(path)
images = []
images = glob.glob(os.path.join(path, '**', '**.png'))
print(len(images))
# Out:
# /home/fquaren/unimib/tesi/data/raw/all/
# 1386

# %%
from sklearn.model_selection import train_test_split
import random

random.shuffle(images)

# %%
len([f for f in images if 'CT' in f])
# Out:
# 585

# %%
len([f for f in images if 'MRI' in f])
# Out:
# 319

# %%
len([f for f in images if 'PET' in f])
# Out:
# 482

# %%
train_val_set, test_set = train_test_split(images, train_size=0.8)
train_set, val_set = train_test_split(train_val_set, train_size=0.9)

# %% [markdown]
# # Unbalanced dataset

# %%
len([f for f in train_set if 'CT' in f])
# Out:
# 426

# %%
len([f for f in train_set if 'MRI' in f])
# Out:
# 227

# %%
len([f for f in train_set if 'PET' in f])
# Out:
# 344

# %%
len(train_set)
# Out:
# 997

# %%
len(val_set)
# Out:
# 111

# %%
len(test_set)
# Out:
# 278

# %%
i = cv2.imread(train_set[1])
plt.imshow(i)

# %%
i = plt.imread('/home/fquaren/unimib/tesi/data/raw/all/MRI/MRI1.png')
plt.imshow(i)
plt.figure(figsize=(10,10))
plt.hist(i.ravel()) #calculating histogram
plt.show()

j = plt.imread('/home/fquaren/unimib/tesi/data/raw/all/MRI/MRI175.png')
plt.imshow(j)
plt.figure(figsize=(10,10))
plt.hist(j.ravel()) #calculating histogram
plt.show()

# %% [markdown]
# # Normalize

# %%
plt.figure(figsize=(10,10))
plt.hist(k) #calculating histogram
plt.show()

# %% [markdown]
# # Move images

# %%
# mv images in train/ val/ test/
os.getcwd()
# Out:
# '/home/fquaren/unimib/tesi/src'

# %%
for i in train_set:
    shutil.move(i, os.path.join(cfg.train_directory, os.path.basename(i)))

# %%
for i in val_set:
    shutil.move(i, os.path.join(cfg.val_directory, os.path.basename(i)))

# %%
for i in test_set:
   shutil.move(i, os.path.join(cfg.test_directory, os.path.basename(i)))

# %%
test_set = np.load('/home/fquaren/unimib/tesi/data/processed/numpy/x_train.npy')

# %%
n = random.randint(0,50)
plt.imshow(test_set[n])
